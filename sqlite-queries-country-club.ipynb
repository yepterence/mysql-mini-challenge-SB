# %%
import os
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd 
import numpy as np

# %%
engine = create_engine('sqlite:///sqlite_db_pythonsqlite.db')

# %%
con = engine.connect()
engine.table_names()
# Out:
# ['Bookings', 'Facilities', 'Members']

# %%
# Task 1
# Produce a list of facilities with a total revenue less than 1000.
# The output of facility name and total revenue, sorted by revenue.
rs = con.execute(''' SELECT DISTINCT f.name as facility, CASE WHEN memid != 0 THEN membercost * slots ELSE guestcost * slots END as total_revenue  
    FROM Bookings as b
    JOIN Facilities as f 
    USING (facid)''')

# %%
# Retrieve the query's results
q10_df = pd.DataFrame(rs.fetchall())

# %%
# Rename columns 
q10_df.columns = ['facility','total_revenue']
# Group the df by facility and sum the values to determine total revenue by facility
tot_rev_by_fac = q10_df.groupby('facility').sum()
# Filter for values less than 1000
tot_rev_by_fac[tot_rev_by_fac['total_revenue'] < 1000]
# Out:
#                  total_revenue
# facility
# Badminton Court          139.5
# Massage Room 2           499.8
# Pool Table                15.0
# Snooker Table             30.0
# Squash Court             637.0
# Table Tennis              10.0
# Tennis Court 1           840.0
# Tennis Court 2           540.0

# %%
# Task 2
# Produce a report of members and who recommended them in alphabetic surname,firstname order
rs = con.execute(''' SELECT memid, surname, firstname, recommendedby
    FROM Members
    ''')

# %%
q11_df = pd.DataFrame(rs.fetchall())
q11_df.columns = ['memid','surname','firstname', 'recommendedby']
q11_df
# Out:
#     memid            surname  firstname recommendedby
# 0       0              GUEST      GUEST
# 1       1              Smith     Darren
# 2       2              Smith      Tracy
# 3       3             Rownam        Tim
# 4       4           Joplette     Janice             1
# 5       5            Butters     Gerald             1
# 6       6              Tracy     Burton
# 7       7               Dare      Nancy             4
# 8       8             Boothe        Tim             3
# 9       9           Stibbons     Ponder             6
# 10     10               Owen    Charles             1
# 11     11              Jones      David             4
# 12     12              Baker       Anne             9
# 13     13            Farrell     Jemima
# 14     14              Smith       Jack             1
# 15     15              Bader   Florence             9
# 16     16              Baker    Timothy            13
# 17     17             Pinker      David            13
# 18     20            Genting    Matthew             5
# 19     21          Mackenzie       Anna             1
# 20     22             Coplin       Joan            16
# 21     24             Sarwin  Ramnaresh            15
# 22     26              Jones    Douglas            11
# 23     27             Rumney  Henrietta            20
# 24     28            Farrell      David
# 25     29  Worthington-Smyth      Henry             2
# 26     30            Purview  Millicent             2
# 27     33         Tupperware   Hyacinth
# 28     35               Hunt       John            30
# 29     36            Crumpet      Erica             2
# 30     37              Smith     Darren

# %%
q11_df['recommendedby'].replace('',np.nan, inplace=True)
# rec_members_combined = recommended.join(members, how='inner',on='recommendedby')
# rec_members_combined
# recommended.dropna(inplace=True)
recommends = q11_df['recommendedby'].dropna().astype('int')

# %%
# Task3
# Find the facilities with their usage by member, but not guests
rs = con.execute(''' SELECT f.name as facility, surname, firstname, slots  
FROM Bookings b 
JOIN Facilities f  
USING (facid)
JOIN Members m 
USING (memid)
WHERE memid != 0
    ''')
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1202             if conn is None:
# -> 1203                 conn = self._revalidate_connection()
#    1204
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _revalidate_connection(self)
#     478             return self.__connection
# --> 479         raise exc.ResourceClosedError("This Connection is closed")
#     480
#
# ResourceClosedError: This Connection is closed
#
# The above exception was the direct cause of the following exception:
#
# StatementError                            Traceback (most recent call last)
# <ipython-input-103-0db2dd8b8e58> in <module>
#       1 # Task3
#       2 # Find the facilities with their usage by member, but not guests
# ----> 3 rs = con.execute(''' SELECT f.name as facility, surname, firstname, slots
#       4 FROM Bookings b
#       5 JOIN Facilities f
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1173         dialect = self.dialect
#    1174         parameters = _distill_params(multiparams, params)
# -> 1175         ret = self._execute_context(
#    1176             dialect,
#    1177             dialect.execution_ctx_cls._init_statement,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1205             context = constructor(dialect, self, conn, *args)
#    1206         except BaseException as e:
# -> 1207             self._handle_dbapi_exception(
#    1208                 e, util.text_type(statement), parameters, None, None
#    1209             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1201                 conn = None
#    1202             if conn is None:
# -> 1203                 conn = self._revalidate_connection()
#    1204
#    1205             context = constructor(dialect, self, conn, *args)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _revalidate_connection(self)
#     477             self.__invalid = False
#     478             return self.__connection
# --> 479         raise exc.ResourceClosedError("This Connection is closed")
#     480
#     481     @property
#
# StatementError: (sqlalchemy.exc.ResourceClosedError) This Connection is closed
# [SQL:  SELECT f.name as facility, surname, firstname, slots
# FROM Bookings b
# JOIN Facilities f
# USING (facid)
# JOIN Members m
# USING (memid)
# WHERE memid != 0
#     ]

# %%
# Task 4 
# Find the facilities usage by month, but not guests
rs = con.execute('''SELECT f.name as facility, slots, starttime
FROM Bookings b 
JOIN Facilities f 
USING (facid)
WHERE memid != 0''')

# %%
con.close()
